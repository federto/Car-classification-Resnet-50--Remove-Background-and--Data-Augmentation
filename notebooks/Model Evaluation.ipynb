# %% [markdown]
# # Vehicle Classification
#
# ## Evaluate your model

# %%
import os
import sys
from pathlib import Path
from sklearn.metrics import accuracy_score, classification_report
from utils import utils
from models import resnet_50

# %% [markdown]
# ## Experiment settings
#
# Set here the two variables in the following way:
#
# - **CONFIG_YML:** assign the path to the config.yml file used for the experiment you want to evaluate
# - **WEIGHTS:** assign the path to the model weights (.h5 file) you want to evaluate

# %%
# Modify this
CONFIG_YML = "../experiments/config_002.yml"
WEIGHTS = "../experiments/exp_002/model.111-0.8154.h5"

# %%
# (!) Don't touch this cell, will load the config file specified before
config = utils.load_config(CONFIG_YML)
config
# Out:
# {'seed': 123,
#  'data': {'directory': '/home/app/src/data/car_ims_v3/train',
#   'labels': 'inferred',
#   'label_mode': 'categorical',
#   'validation_split': 0.2,
#   'image_size': [224, 224],
#   'batch_size': 32},
#  'model': {'weights': 'imagenet',
#   'input_shape': [224, 224, 3],
#   'classes': 196,
#   'dropout_rate': 0.9,
#   'data_aug_layer': {'random_flip': {'name': 'random_flip',
#     'mode': 'horizontal'},
#    'random_rotation': {'name': 'random_rotation', 'factor': 0.05},
#    'random_zoom': {'name': 'random_zoom',
#     'height_factor': 0.1,
#     'width_factor': 0.1}}},
#  'compile': {'optimizer': {'adam': {'learning_rate': 1e-05}},
#   'loss': 'categorical_crossentropy',
#   'metrics': ['accuracy']},
#  'fit': {'epochs': 150,
#   'callbacks': {'model_checkpoint': {'filepath': '/home/app/src/experiments/exp_002/model.{epoch:02d}-{val_loss:.4f}.h5',
#     'save_best_only': True},
#    'tensor_board': {'log_dir': '/home/app/src/experiments/exp_002/logs'}}}}

# %%
# (!) Don't touch this cell, will use the config file to infer the class names
#     and also to load the corresponding testing dataset.
#     If you get an error, you must review your data/code.

MODEL_CLASSES = utils.get_class_names(config)

if len(MODEL_CLASSES) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your data!"
    )

_dirname, _ = os.path.split(config['data']['directory'])
TEST_FOLDER = os.path.join(_dirname, 'test')

if not os.path.exists(TEST_FOLDER):
    raise ValueError("'test' folder not found!")
    
if len(os.listdir(TEST_FOLDER)) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your testing dataset!"
    )
    
if set(os.listdir(TEST_FOLDER)) != set(MODEL_CLASSES):
    raise ValueError(
        "The name of the subfolders inside your test set "
        "doesn't match with the model classes!"
    )

# %% [markdown]
# ## Load your model
#
# Use `resnet_50.create_model()` and remember to properly setup the model weights!
#
# Assign the model to the variable `cnn_model`.

# %%
# Complete this
# TODO
cnn_model = resnet_50.create_model(WEIGHTS)

# It should print your model correctly
print(cnn_model.summary())
# Out:
# 2022-09-27 10:34:02.701600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:02.734473: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:02.735455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:02.742579: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-27 10:34:02.743203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:02.744151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:02.745020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:03.709390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:03.710389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:03.711315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 10:34:03.712194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9583 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 196)               401604
#
# =================================================================
# Total params: 23,989,316
# Trainable params: 23,936,196
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %% [markdown]
# ## Get predictions from testing dataset

# %%
# (!) Don't touch this cell, will use the loaded model and
#     the function utils.predict_from_folder() to get 
#     model predictions and the corresponding true labels
#     so we can measure the accuracy

predictions, labels = utils.predict_from_folder(
    folder=TEST_FOLDER, 
    model=cnn_model, 
    input_size=config["data"]["image_size"], 
    class_names=MODEL_CLASSES,
)

if len(predictions) != len(labels):
    raise ValueError(
        "The lenght of predictions and labels lists doesn't match!"
    )

if not isinstance(predictions[0], str):
    raise ValueError(
        "Model predictions should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

if not isinstance(labels[0], str):
    raise ValueError(
        "Ground true labels should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )
# Out:
# 2022-09-27 10:34:29.663483: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-09-27 10:34:30.110386: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-27 10:34:30.112006: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-27 10:34:30.112310: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-09-27 10:34:30.118371: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-27 10:34:30.119216: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.

# %%
# (!) Don't touch this cell

print(classification_report(y_true=labels, y_pred=predictions))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             AM General Hummer SUV 2000       0.82      0.95      0.88        44
#                              Acura Integra Type R 2001       0.86      0.86      0.86        44
#                                    Acura RL Sedan 2012       0.67      0.69      0.68        32
#                                    Acura TL Sedan 2012       0.61      0.93      0.73        43
#                                   Acura TL Type-S 2008       0.87      0.93      0.90        42
#                                   Acura TSX Sedan 2012       0.88      0.55      0.68        40
#                               Acura ZDX Hatchback 2012       0.71      0.69      0.70        39
#               Aston Martin V8 Vantage Convertible 2012       0.44      0.64      0.52        45
#                     Aston Martin V8 Vantage Coupe 2012       0.53      0.20      0.29        41
#                   Aston Martin Virage Convertible 2012       0.70      0.42      0.53        33
#                         Aston Martin Virage Coupe 2012       0.78      0.84      0.81        38
#                                    Audi 100 Sedan 1994       0.45      0.72      0.55        40
#                                    Audi 100 Wagon 1994       0.61      0.45      0.52        42
#                                     Audi A5 Coupe 2012       0.49      0.80      0.61        41
#                                     Audi R8 Coupe 2012       0.91      0.72      0.81        43
#                             Audi RS 4 Convertible 2008       0.59      0.61      0.60        36
#                                     Audi S4 Sedan 2007       0.61      0.51      0.55        45
#                                     Audi S4 Sedan 2012       0.36      0.33      0.35        39
#                               Audi S5 Convertible 2012       0.58      0.36      0.44        42
#                                     Audi S5 Coupe 2012       0.35      0.21      0.26        42
#                                     Audi S6 Sedan 2011       0.74      0.87      0.80        46
#                                 Audi TT Hatchback 2011       0.55      0.60      0.57        40
#                                  Audi TT RS Coupe 2012       0.61      0.77      0.68        39
#                                    Audi TTS Coupe 2012       0.59      0.40      0.48        42
#                                     Audi V8 Sedan 1994       0.66      0.58      0.62        43
#                          BMW 1 Series Convertible 2012       0.67      0.63      0.65        35
#                                BMW 1 Series Coupe 2012       0.72      0.68      0.70        41
#                                BMW 3 Series Sedan 2012       0.63      0.74      0.68        42
#                                BMW 3 Series Wagon 2012       0.81      0.73      0.77        41
#                          BMW 6 Series Convertible 2007       0.72      0.52      0.61        44
#                          BMW ActiveHybrid 5 Sedan 2012       0.94      0.91      0.93        34
#                             McLaren MP4-12C Coupe 2012       0.91      0.93      0.92        44
#               Mercedes-Benz 300-Class Convertible 1993       0.61      0.79      0.69        48
#                       Mercedes-Benz C-Class Sedan 2012       1.00      0.76      0.86        45
#                       Mercedes-Benz E-Class Sedan 2012       0.76      0.81      0.79        43
#                       Mercedes-Benz S-Class Sedan 2012       0.97      0.89      0.93        44
#                      Mercedes-Benz SL-Class Coupe 2009       0.79      0.83      0.81        36
#                        Mercedes-Benz Sprinter Van 2012       0.80      0.90      0.85        41
#                           Mitsubishi Lancer Sedan 2012       0.63      0.83      0.72        47
#                                Nissan 240SX Coupe 1998       0.73      0.87      0.79        46
#                             Nissan Juke Hatchback 2012       0.88      0.84      0.86        44
#                             Nissan Leaf Hatchback 2012       0.87      0.95      0.91        42
#                           Nissan NV Passenger Van 2012       0.92      0.89      0.91        38
#                               Plymouth Neon Coupe 1999       1.00      0.84      0.91        44
#                            Porsche Panamera Sedan 2012       0.92      0.84      0.88        43
#                         Ram C-V Cargo Van Minivan 2012       0.77      0.73      0.75        41
#                           Rolls-Royce Ghost Sedan 2012       0.80      0.87      0.84        38
#    Rolls-Royce Phantom Drophead Coupe Convertible 2012       0.55      0.60      0.57        30
#                         Rolls-Royce Phantom Sedan 2012       0.77      0.68      0.72        44
#                                Scion xD Hatchback 2012       0.73      0.85      0.79        41
#                             Spyker C8 Convertible 2009       0.90      0.80      0.85        45
#                                   Spyker C8 Coupe 2009       0.87      0.62      0.72        42
#                                Suzuki Aerio Sedan 2007       0.67      0.74      0.70        38
#                              Suzuki Kizashi Sedan 2012       0.70      0.80      0.75        46
#                              Suzuki SX4 Hatchback 2012       0.78      0.83      0.80        42
#                                  Suzuki SX4 Sedan 2012       0.69      0.60      0.64        40
#                               Tesla Model S Sedan 2012       0.62      0.89      0.73        38
#                                Toyota 4Runner SUV 2012       0.76      0.95      0.84        40
#                                Toyota Camry Sedan 2012       0.74      0.79      0.76        43
#                              Toyota Corolla Sedan 2012       0.78      0.58      0.67        43
#                                Toyota Sequoia SUV 2012       0.97      0.87      0.92        38
#                       Volkswagen Beetle Hatchback 2012       0.98      0.95      0.96        42
#                         Volkswagen Golf Hatchback 1991       0.73      1.00      0.84        46
#                         Volkswagen Golf Hatchback 2012       0.91      0.72      0.81        43
#                                   Volvo 240 Sedan 1993       0.86      0.96      0.91        45
#                               Volvo C30 Hatchback 2012       0.88      0.90      0.89        41
#                                    Volvo XC90 SUV 2007       0.85      0.77      0.80        43
#                          smart fortwo Convertible 2012       0.89      0.78      0.83        40
#
#                                               accuracy                           0.77      8041
#                                              macro avg       0.78      0.77      0.77      8041
#                                           weighted avg       0.78      0.77      0.77      8041

# %%
# (!) Don't touch this cell

acc = accuracy_score(y_true=labels, y_pred=predictions)

print(f"Your model accuracy is {acc:.4f}!")

if acc < .3:
    raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
# Out:
# Your model accuracy is 0.7688!
